# %%
# oxides 1-4 individual plots (Bomdila village)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\1.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
# Using LaTeX for subscripts: $_2$ for subscript 2, $_3$ for subscript 3
depth = [0.25, 0.5, 0.75, 1, 2, 3, 4, 5]
oxides = {
    r'SiO$_2$ wt%': [66.89, 67.12, 63.39, 65.06, 61.23, 64.05, 61.86, 62.34],
    r'Al$_2$O$_3$ wt%': [17.68, 17.7, 14.82, 16.63, 10.21, 11.24, 10.63, 11.92],
    r'Fe$_2$O$_3$ wt%': [9.89, 5.74, 2.91, 5.32, 2.29, 2.31, 2.56, 3.25],
    r'MgO wt%': [2.36, 1.29, 0.72, 1.42, 0.85, 0.61, 0.81, 0.63]
}

bedrock = {
    r'SiO$_2$ wt%': 73.34, 
    r'Al$_2$O$_3$ wt%': 14.26, 
    r'Fe$_2$O$_3$ wt%': 3.27, 
    r'MgO wt%': 0.73
}

# --- PLOTTING ---
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82) # Adjusted top for titles

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # High visibility lines/markers
    ax.plot(values, depth, marker='o', color='black', markersize=12, linewidth=4)
    
    # Bedrock reference
    ax.scatter(bedrock[name], 5.8, color='blue', marker='o', s=150, label='Bedrock' if i==0 else "", zorder=5)
    ax.axhline(y=5.5, color='black', linestyle='--', linewidth=3) 
    
    # Axis formatting
    # Note: fontweight='bold' doesn't always apply to LaTeX parts, 
    # but the font size makes it very readable.
    ax.set_title(name, fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth (m)', fontsize=26)
        ax.set_ylim(6.4, 0) # Inverted Y-axis
        ax.legend(loc='lower left', fontsize=20, frameon=True, edgecolor='black')
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\1.svg

# %%
# oxides 5-8 individual plots (Bomdila village)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\1.1.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
# Using LaTeX for subscripts: $_2$ for subscript 2, $_3$ for subscript 3
depth = [0.25, 0.5, 0.75, 1, 2, 3, 4, 5]
oxides = {
    r'CaO wt%': [0.46, 0.69, 0.85, 0.67, 0.64, 0.73, 0.75, 0.62],
    r'Na$_2$O wt%': [0.29, 0.85, 1.44, 1.03, 1.88, 1.9, 1.57, 1.14],
    r'K$_2$O wt%': [2.04, 2.98, 4.22, 1.66, 5.34, 5.66, 6.28, 5.12],
    r'TiO$_2$ wt%': [1.64, 0.82, 0.45, 0.89, 0.44, 0.45, 0.51, 0.54]
}

bedrock = {
    r'CaO wt%': 0.97, 
    r'Na$_2$O wt%': 2.64, 
    r'K$_2$O wt%': 4.54, 
    r'TiO$_2$ wt%': 0.37
}

# --- PLOTTING ---
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82) # Adjusted top for titles

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # High visibility lines/markers
    ax.plot(values, depth, marker='o', color='black', markersize=12, linewidth=4)
    
    # Bedrock reference
    ax.scatter(bedrock[name], 5.8, color='blue', marker='o', s=150, label='Bedrock' if i==0 else "", zorder=5)
    ax.axhline(y=5.5, color='black', linestyle='--', linewidth=3) 
    
    # Axis formatting
    # Note: fontweight='bold' doesn't always apply to LaTeX parts, 
    # but the font size makes it very readable.
    ax.set_title(name, fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth (m)', fontsize=26)
        ax.set_ylim(6.4, 0) # Inverted Y-axis
        ax.legend(loc='lower left', fontsize=20, frameon=True, edgecolor='black')
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

#plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\1.1.svg

# %%
# All oxides in one plot with wt% or log wt% (Bomdila village)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_1.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
depth = [0.25, 0.5, 0.75, 1, 2, 3, 4, 5]
bedrock_depth = 5.8  # Reference depth for bedrock points

# Data from your table (Last row is Bedrock)
oxide_data = {
    'SiO$_2$':    {'v': [66.89, 67.12, 63.39, 65.06, 61.23, 64.05, 61.86, 62.34, 73.34], 'm': 'o', 'c': '#e41a1c', 'ls': '-'},
    'Al$_2$O$_3$':   {'v': [17.68, 17.70, 14.82, 16.63, 10.21, 11.24, 10.63, 11.92, 14.26], 'm': 's', 'c': '#377eb8', 'ls': '-'},
    'Fe$_2$O$_3$':   {'v': [9.89, 5.74, 2.91, 5.32, 2.29, 2.31, 2.56, 3.25, 3.27], 'm': '^', 'c': '#4daf4a', 'ls': '-'},
    'MgO':      {'v': [2.36, 1.29, 0.72, 1.42, 0.85, 0.61, 0.81, 0.63, 0.73], 'm': 'D', 'c': '#984ea3', 'ls': '-'},
    'CaO':      {'v': [0.46, 0.69, 0.85, 0.67, 0.64, 0.73, 0.75, 0.62, 0.97], 'm': 'v', 'c': '#ff7f00', 'ls': '-'},
    'Na$_2$O':    {'v': [0.29, 0.85, 1.44, 1.03, 1.88, 1.90, 1.57, 1.14, 2.64], 'm': 'p', 'c': '#a65628', 'ls': '-'},
    'K$_2$O':     {'v': [2.04, 2.98, 4.22, 1.66, 5.34, 5.66, 6.28, 5.12, 4.54], 'm': 'h', 'c': '#f781bf', 'ls': '-'},
    'TiO$_2$':    {'v': [1.64, 0.82, 0.45, 0.89, 0.44, 0.45, 0.51, 0.54, 0.37], 'm': '*', 'c': '#999999', 'ls': '-'}
}

# --- PLOTTING ---
fig, ax = plt.subplots(figsize=(10, 8))

for name, info in oxide_data.items():
    values = info['v']
    # Plot profile (excluding last index/bedrock)
    ax.plot(values[:-1], depth, label=name, marker=info['m'], color=info['c'], 
            linestyle=info['ls'], linewidth=2, markersize=9, alpha=0.8)
    # Bedrock reference
    ax.axhline(y=5.5, color='black', linestyle='--', linewidth=3) 
    
    # Plot bedrock points as separate markers at the bottom
    ax.scatter(values[-1], bedrock_depth, marker=info['m'], color=info['c'], 
               s=120, edgecolors='black', zorder=5)
    
# --- FORMATTING ---
ax.set_xlabel('Oxides (wt.%)', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylabel('Depth (m)', fontsize=16, fontweight='bold')

# Depth profile standard: 0 at top, Bedrock at bottom
ax.set_ylim(6.5, 0) 
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

# Log scale is often useful when SiO2 (60+) and CaO (<1) are on the same plot
# Uncomment the line below if you want to see small variations better:
ax.set_xscale('log') 

ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(True, which="both", linestyle='-', alpha=0.3, linewidth=1.5)

# Legend placed outside to the right
ax.legend(title="Oxides", title_fontsize=14, loc='center left', 
          bbox_to_anchor=(1, 0.5), fontsize=12, frameon=True)

plt.title('Depth-alteration Profile (Log Scale)', fontsize=20, fontweight='bold', pad=60)

# --- ADD BEDROCK TEXT (CALCULATED CENTER) ---
import numpy as np

# 1. Get current X-axis limits (in log scale)
xmin, xmax = ax.get_xlim()

# 2. Find the center in log-space and convert back to data units
# This ensures it is visually centered on a log scale
log_center = 10**((np.log10(xmin) + np.log10(xmax)) / 2)

# 3. Add the text at depth 5.3
ax.text(log_center, 5.3, 'Bedrock', 
        fontsize=14, 
        fontweight='bold', 
        color='black', 
        ha='center', 
        va='center', 
        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

# --- SAVE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Success! Plot saved to: {output_file_path}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Success! Plot saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_1.svg

# %%
# oxides 1-4 individual plots (Anini, Arunachal Himalaya)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\2.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
# Using LaTeX for subscripts: $_2$ for subscript 2, $_3$ for subscript 3
depth = [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5]
oxides = {
    r'SiO$_2$ wt%': [50.9, 51.0, 51.5, 51.4, 48.1, 49.0, 49.1, 50.7, 51.2, 51.5, 52.2],
    r'Al$_2$O$_3$ wt%': [15.47, 16.41, 16.24, 16.36, 17.32, 17.31, 17.13, 17.0, 16.3, 16.1, 15.81],
    r'Fe$_2$O$_3$ wt%': [4.15, 7.6, 9.21, 12.01, 14.7, 13.31, 10.84, 10.44, 9.59, 10.49, 9.42],
    r'MgO wt%': [1.46, 1.51, 2.16, 2.42, 2.98, 3.12, 3.68, 3.65, 4.64, 4.45, 4.84]
}


# --- PLOTTING ---
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82) # Adjusted top for titles

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # High visibility lines/markers
    ax.plot(values, depth, marker='o', color='black', markersize=12, linewidth=4)
    
    
    # Axis formatting
    # Note: fontweight='bold' doesn't always apply to LaTeX parts, 
    # but the font size makes it very readable.
    ax.set_title(name, fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth (m)', fontsize=26)
        ax.set_ylim(2.55, -0.07) # Inverted Y-axis
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\2.svg

# %%
# oxides 5-8 individual plots (Anini, Arunachal Himalaya)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\2.1.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
# Using LaTeX for subscripts: $_2$ for subscript 2, $_3$ for subscript 3
depth = [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5]
oxides = {
    r'CaO wt%': [0.59, 0.57, 0.46, 0.46, 0.48, 0.95, 2.73, 4.75, 7.86, 8.14, 9.39],
    r'Na$_2$O wt%': [0.27, 0.28, 0.29, 0.29, 0.26, 0.35, 0.72, 2.05, 2.78, 3.12, 3.33],
    r'K$_2$O wt%': [1.65, 1.71, 2.02, 2.25, 2.13, 1.94, 1.54, 1.0, 0.87, 0.76, 0.66],
    r'TiO$_2$ wt%': [0.92, 0.92, 1.27, 1.27, 1.27, 1.3, 1.22, 0.8, 0.98, 0.93, 0.89]
}

# --- PLOTTING ---
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82) # Adjusted top for titles

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # High visibility lines/markers
    ax.plot(values, depth, marker='o', color='black', markersize=12, linewidth=4)
    
    
    # Axis formatting
    # Note: fontweight='bold' doesn't always apply to LaTeX parts, 
    # but the font size makes it very readable.
    ax.set_title(name, fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth (m)', fontsize=26)
        ax.set_ylim(2.55, -0.07) # Inverted Y-axis
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

#plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\2.1.svg

# %%
# All oxides in one plot with wt% or log wt% (Anini, Arunachal Himalaya)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_2.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
depth = [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5]

# Data from your table (Last row is Bedrock)
# --- DATA FROM IMAGE ---
oxide_data = {
    'SiO$_2$':    {'v': [50.9, 51.0, 51.5, 51.4, 48.1, 49.0, 49.1, 50.7, 51.2, 51.5, 52.2], 'm': 'o', 'c': '#e41a1c', 'ls': '-'},
    'Al$_2$O$_3$':   {'v': [15.47, 16.41, 16.24, 16.36, 17.32, 17.31, 17.13, 17.0, 16.3, 16.1, 15.81], 'm': 's', 'c': '#377eb8', 'ls': '-'},
    'Fe$_2$O$_3$':   {'v': [4.15, 7.6, 9.21, 12.01, 14.7, 13.31, 10.84, 10.44, 9.59, 10.49, 9.42], 'm': '^', 'c': '#4daf4a', 'ls': '-'},
    'MgO':      {'v': [1.46, 1.51, 2.16, 2.42, 2.98, 3.12, 3.68, 3.65, 4.64, 4.45, 4.84], 'm': 'D', 'c': '#984ea3', 'ls': '-'},
    'CaO':      {'v': [0.59, 0.57, 0.46, 0.46, 0.48, 0.95, 2.73, 4.75, 7.86, 8.14, 9.39], 'm': 'v', 'c': '#ff7f00', 'ls': '-'},
    'Na$_2$O':    {'v': [0.27, 0.28, 0.29, 0.29, 0.26, 0.35, 0.72, 2.05, 2.78, 3.12, 3.33], 'm': 'p', 'c': '#a65628', 'ls': '-'},
    'K$_2$O':     {'v': [1.65, 1.71, 2.02, 2.25, 2.13, 1.94, 1.54, 1.0, 0.87, 0.76, 0.66], 'm': 'h', 'c': '#f781bf', 'ls': '-'},
    'TiO$_2$':    {'v': [0.92, 0.92, 1.27, 1.27, 1.27, 1.3, 1.22, 0.8, 0.98, 0.93, 0.89], 'm': '*', 'c': '#999999', 'ls': '-'}
}


# --- PLOTTING ---
fig, ax = plt.subplots(figsize=(10, 8))

for name, info in oxide_data.items():
    values = info['v']
    # Plot profile
    ax.plot(values[:], depth, label=name, marker=info['m'], color=info['c'], 
            linestyle=info['ls'], linewidth=2, markersize=9, alpha=0.8)
   
    
# --- FORMATTING ---
ax.set_xlabel('Oxides (wt.%)', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylabel('Depth (m)', fontsize=16, fontweight='bold')

# Depth profile standard: 0 at top, Bedrock at bottom
ax.set_ylim(2.75, -0.07) 
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

# Log scale is often useful when SiO2 (60+) and CaO (<1) are on the same plot
# Uncomment the line below if you want to see small variations better:
ax.set_xscale('log') 

ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(True, linestyle='-', which="both", alpha=0.3, linewidth=1.5)

# Legend placed outside to the right
ax.legend(title="Oxides", title_fontsize=14, loc='center left', 
          bbox_to_anchor=(1, 0.5), fontsize=12, frameon=True)

plt.title('Depth-alteration Profile (Log Scale)', fontsize=20, fontweight='bold', pad=60)


# --- ADD BEDROCK NOT EXPOSED TEXT (CALCULATED CENTER) ---
import numpy as np

# 1. Get current X-axis limits (in log scale)
xmin, xmax = ax.get_xlim()

# 2. Find the center in log-space and convert back to data units
# This ensures it is visually centered on a log scale
log_center = 10**((np.log10(xmin) + np.log10(xmax)) / 2)

# 3. Add the text at depth 5.3
ax.text(log_center, 2.65, 'Bedrock not exposed', 
        fontsize=14, 
        fontweight='bold', 
        color='black', 
        ha='center', 
        va='center', 
        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))


# --- SAVE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Success! Plot saved to: {output_file_path}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Success! Plot saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_2.svg

# %%
# oxides 1-4 individual plots (Kanjirapalli series)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\3.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
# Using the mid-points or representative labels for the depth intervals
depth_labels = ["0-13", "13-32", "32-56", "56-83", "83-112", "112-150"]
# Numerical representation for plotting on Y-axis (using index for even spacing)
y_coords = list(range(len(depth_labels)))

oxides = {
    r'SiO$_2$': [45.4, 37.9, 37.3, 36.1, 33.7, 33],
    r'Al$_2$O$_3$': [26.1, 27.3, 30.9, 27.6, 30, 31.3],
    r'Fe$_2$O$_3$': [6.4, 12.7, 11.6, 14.9, 14.9, 12.7],
    r'MgO': [0.74, 0.49, 0.67, 0.48, 0.31, 0.29]
}

# --- PLOTTING ---
# width to fit 4 plots comfortably
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82)

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # Plotting values against numerical indices
    ax.plot(values, y_coords, marker='o', color='black', markersize=12, linewidth=4)
    
    # Axis formatting
    ax.set_title(name + " wt%", fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth Interval (cm)', fontsize=26)
        ax.set_yticks(y_coords)
        ax.set_yticklabels(depth_labels)
        ax.invert_yaxis() # Top depth at the top
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\3.svg

# %%
# oxides 5-8 individual plots (Kanjirapalli series)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\3.1.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
# Using the mid-points or representative labels for the depth intervals
depth_labels = ["0-13", "13-32", "32-56", "56-83", "83-112", "112-150"]
# Numerical representation for plotting on Y-axis (using index for even spacing)
y_coords = list(range(len(depth_labels)))

oxides = {
   r'CaO': [0.74, 0.46, 0.54, 0.57, 0.52, 0.42],
    r'Na$_2$O': [0.54, 0.17, 0.17, 0.19, 0.13, 0.15],
    r'K$_2$O': [0.52, 0.51, 0.53, 0.63, 0.65, 0.5],
    r'TiO$_2$': [1.1, 1.1, 1, 1.1, 1.2, 1.2]
}

# --- PLOTTING ---
# width to fit 4 plots comfortably
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82)

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # Plotting values against numerical indices
    ax.plot(values, y_coords, marker='o', color='black', markersize=12, linewidth=4)
    
    # Axis formatting
    ax.set_title(name + " wt%", fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth Interval (cm)', fontsize=26)
        ax.set_yticks(y_coords)
        ax.set_yticklabels(depth_labels)
        ax.invert_yaxis() # Top depth at the top
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

#plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\3.1.svg

# %%
# All oxides in one plot with wt% or log wt% (Kanjirapalli series)
import matplotlib.pyplot as plt
import os
import numpy as np

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_3.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
# Depth intervals as labels
depth_labels = ["0-13", "13-32", "32-56", "56-83", "83-112", "112-150"]
# Numerical coordinates for plotting (0 to 5)
y_coords = list(range(len(depth_labels)))

# Data from your provided table
oxide_data = {
    'SiO$_2$':    {'v': [45.4, 37.9, 37.3, 36.1, 33.7, 33],   'm': 'o', 'c': '#e41a1c', 'ls': '-'},
    'Al$_2$O$_3$':   {'v': [26.1, 27.3, 30.9, 27.6, 30, 31.3],  'm': 's', 'c': '#377eb8', 'ls': '-'},
    'Fe$_2$O$_3$':   {'v': [6.4, 12.7, 11.6, 14.9, 14.9, 12.7], 'm': '^', 'c': '#4daf4a', 'ls': '-'},
    'MgO':      {'v': [0.74, 0.49, 0.67, 0.48, 0.31, 0.29], 'm': 'D', 'c': '#984ea3', 'ls': '-'},
    'CaO':      {'v': [0.74, 0.46, 0.54, 0.57, 0.52, 0.42], 'm': 'v', 'c': '#ff7f00', 'ls': '-'},
    'Na$_2$O':    {'v': [0.54, 0.17, 0.17, 0.19, 0.13, 0.15], 'm': 'p', 'c': '#a65628', 'ls': '-'},
    'K$_2$O':     {'v': [0.52, 0.51, 0.53, 0.63, 0.65, 0.5],  'm': 'h', 'c': '#f781bf', 'ls': '-'},
    'TiO$_2$':    {'v': [1.1, 1.1, 1, 1.1, 1.2, 1.2],         'm': '*', 'c': '#999999', 'ls': '-'}
}

# --- PLOTTING ---
fig, ax = plt.subplots(figsize=(10, 8))

for name, info in oxide_data.items():
    ax.plot(info['v'], y_coords, label=name, marker=info['m'], color=info['c'], 
            linestyle=info['ls'], linewidth=2, markersize=9, alpha=0.8)
   
# --- FORMATTING ---
ax.set_xlabel('Oxides (wt.%)', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylabel('Depth Interval (cm)', fontsize=16, fontweight='bold')

# Log scale to handle the range between SiO2 (~45) and Na2O/MgO (<1)
ax.set_xscale('log') 

# Set custom Y-axis ticks using the labels
ax.set_yticks(y_coords)
ax.set_yticklabels(depth_labels)
ax.set_ylim(max(y_coords) + 0.5, min(y_coords) - 0.5) # Invert axis: 0-13 at top

ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(True, which="both", linestyle='-', alpha=0.3, linewidth=1.5)

# Legend
ax.legend(title="Oxides", title_fontsize=14, loc='center left', 
          bbox_to_anchor=(1, 0.5), fontsize=12, frameon=True)

plt.title('Depth-alteration Profile (Log Scale)', fontsize=20, fontweight='bold', pad=60)

# --- ADD BEDROCK TEXT ---
xmin, xmax = ax.get_xlim()
log_center = 10**((np.log10(xmin) + np.log10(xmax)) / 2)
# Placing text slightly below the last data point (index 5)
ax.text(log_center, 5.3, 'Bedrock not exposed', 
        fontsize=14, fontweight='bold', color='black', ha='center', va='center', 
        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

# --- SAVE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Success! Plot saved to: {output_file_path}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Success! Plot saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_3.svg

# %%
# oxides 1-4 individual plots (Madayi village)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\4.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
depth = [0, 2.2, 3.7, 4.2, 4.7, 5.2]

# Only the first 4 oxides as requested
oxides = {
    r'SiO$_2$ wt%': [9.88, 18.9, 20.8, 42.1, 46.9, 47.6],
    r'Al$_2$O$_3$ wt%': [27.1, 36.3, 40.8, 32.1, 29.2, 30.5],
    r'Fe$_2$O$_3$ wt%': [51.7, 34.3, 17.1, 9.39, 7.11, 8.81],
    r'MgO wt%': [0, 0, 0.21, 0.1, 0.13, 0.09]
}

# --- PLOTTING ---
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82) 

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # High visibility lines/markers
    ax.plot(values, depth, marker='o', color='black', markersize=12, linewidth=4)
    
    # Axis formatting
    ax.set_title(name, fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth (m)', fontsize=26)
        # Updated Y-limit to fit 5.2m depth (Inverted)
        ax.set_ylim(5.5, -0.07) 
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\4.svg

# %%
# oxides 5-8 individual plots (Madayi village)
import matplotlib.pyplot as plt
import os

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\4.1.svg"
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# --- DATA ---
depth = [0, 2.2, 3.7, 4.2, 4.7, 5.2]

# Only the first 4 oxides as requested
oxides = {
    r'CaO': [0.06, 0.11, 0.05, 0.23, 0.25, 0.18],
    r'Na$_2$O': [0, 0, 0, 0.07, 0.02, 0.07],
    r'K$_2$O': [0.02, 0.02, 0.8, 0.22, 0.2, 0.14],
    r'TiO$_2$': [1.87, 2.33, 3.46, 1.95, 1.9, 1.7]
}

# --- PLOTTING ---
fig, axes = plt.subplots(1, 4, figsize=(20, 14), sharey=True)
plt.subplots_adjust(wspace=0.2, top=0.82) 

for i, (name, values) in enumerate(oxides.items()):
    ax = axes[i]
    
    # High visibility lines/markers
    ax.plot(values, depth, marker='o', color='black', markersize=12, linewidth=4)
    
    # Axis formatting
    ax.set_title(name, fontsize=26, pad=20) 
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax.tick_params(axis='both', which='major', labelsize=22, width=2, length=6)
    
    if i == 0:
        ax.set_ylabel('Depth (m)', fontsize=26)
        # Updated Y-limit to fit 5.2m depth (Inverted)
        ax.set_ylim(5.5, -0.07) 
    
    ax.grid(True, linestyle='-', alpha=0.3, linewidth=1.5)

#plt.suptitle('Depth-alteration Profiles', fontsize=32, fontweight='bold', y=0.98)

# --- SAVE FILE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Successfully saved plot to: {output_file_path}")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# Successfully saved plot to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\4.1.svg

# %%
# All oxides in one plot with wt% or log wt% (Madayi village)
import matplotlib.pyplot as plt
import os
import numpy as np
from matplotlib.ticker import FixedLocator, FixedFormatter

# --- CONFIGURATION ---
output_file_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_4.svg"
# os.makedirs(os.path.dirname(output_file_path), exist_ok=True) # Commented out for general use

# --- DATA ---
depth = [0, 2.2, 3.7, 4.2, 4.7, 5.2]

# RECTIFICATION: Used 0.02 for "zero" values to align with the manual "0" tick
oxide_data = {
    'SiO$_2$':    {'v': [9.88, 18.9, 20.8, 42.1, 46.9, 47.6], 'm': 'o', 'c': '#e41a1c', 'ls': '-'},
    'Al$_2$O$_3$':   {'v': [27.1, 36.3, 40.8, 32.1, 29.2, 30.5], 'm': 's', 'c': '#377eb8', 'ls': '-'},
    'Fe$_2$O$_3$':   {'v': [51.7, 34.3, 17.1, 9.39, 7.11, 8.81], 'm': '^', 'c': '#4daf4a', 'ls': '-'},
    'MgO':      {'v': [0.02, 0.02, 0.21, 0.1, 0.13, 0.09], 'm': 'D', 'c': '#984ea3', 'ls': '-'},
    'CaO':      {'v': [0.06, 0.11, 0.05, 0.23, 0.25, 0.18], 'm': 'v', 'c': '#ff7f00', 'ls': '-'},
    'Na$_2$O':    {'v': [0.02, 0.02, 0.02, 0.07, 0.02, 0.07], 'm': 'p', 'c': '#a65628', 'ls': '-'},
    'K$_2$O':     {'v': [0.02, 0.02, 0.8, 0.22, 0.2, 0.14], 'm': 'h', 'c': '#f781bf', 'ls': '-'},
    'TiO$_2$':    {'v': [1.87, 2.33, 3.46, 1.95, 1.9, 1.7], 'm': '*', 'c': '#999999', 'ls': '-'}
}

# --- PLOTTING ---
fig, ax = plt.subplots(figsize=(10, 8))

for name, info in oxide_data.items():
    ax.plot(info['v'], depth, label=name, marker=info['m'], color=info['c'], 
            linestyle=info['ls'], linewidth=2, markersize=9, alpha=0.8)
   
# --- FORMATTING ---
ax.set_xscale('log') 
ax.set_xlabel('Oxides (wt.%)', fontsize=16, fontweight='bold', labelpad=15)
ax.set_ylabel('Depth (m)', fontsize=16, fontweight='bold')

# Set limits and move axis to top
ax.set_xlim(0.015, 100) 
ax.set_ylim(5.7, -0.2) 
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')

# --- MANUAL TICK LABELS ---
# Define positions for ticks and the custom labels (First label is '0')
ticks = [0.02, 0.1, 1, 10, 100]
labels = ['0', '$10^{-1}$', '$10^{0}$', '$10^{1}$', ''] 

ax.xaxis.set_major_locator(FixedLocator(ticks))
ax.xaxis.set_major_formatter(FixedFormatter(labels))

ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid(True, linestyle='-', which="both", alpha=0.3, linewidth=1.5)

# Legend
ax.legend(title="Oxides", title_fontsize=14, loc='center left', 
          bbox_to_anchor=(1, 0.5), fontsize=12, frameon=True)

plt.title('Depth-alteration Profile (Log Scale)', fontsize=20, fontweight='bold', pad=60)

# --- ADD BEDROCK NOT EXPOSED TEXT ---
xmin, xmax = ax.get_xlim()
log_center = 10**((np.log10(xmin) + np.log10(xmax)) / 2)

ax.text(log_center, 5.5, 'Bedrock not exposed', 
        fontsize=14, fontweight='bold', color='black', 
        ha='center', va='center', 
        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

# --- SAVE ---
try:
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    print(f"Success! Plot saved to: {output_file_path}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Success! Plot saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\oxides_log_4.svg

# %%
# Bomdila village
import pandas as pd
import matplotlib.pyplot as plt
import os

# --- 1. CONFIGURATION ---
output_folder = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\Himalaya_1"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# HIGH READABILITY SETTINGS (Optimized for A4 at 30cm)
plt.rcParams.update({
    'font.size': 13,            # Base font size increased
    'axes.labelsize': 11,       # Axis labels
    'axes.titlesize': 12,       # Plot titles
    'legend.fontsize': 9,      # Legend text
    'xtick.labelsize': 9,      # Tick labels
    'ytick.labelsize': 9,
    'lines.linewidth': 1.5,     # Significantly thicker lines
    'lines.markersize': 5,      # Larger markers for quick identification
    'axes.linewidth': 1,      # Thicker axis spines
    'grid.linewidth': 0.5,      # Visible but not distracting grid
    'font.family': 'sans-serif' # Cleaner for technical reading
})

# --- 2. DATA & CALCULATIONS ---
data = {
    'Depth': [0.25, 0.5, 0.75, 1, 2, 3, 4, 5, 6.0], 
    'SiO2': [66.89, 67.12, 63.39, 65.06, 61.23, 64.05, 61.86, 62.34, 73.34],
    'Al2O3': [17.68, 17.7, 14.82, 16.63, 10.21, 11.24, 10.63, 11.92, 14.26],
    'MgO': [2.36, 1.29, 0.72, 1.42, 0.85, 0.61, 0.81, 0.63, 0.73],
    'CaO': [0.46, 0.69, 0.85, 0.67, 0.64, 0.73, 0.75, 0.62, 0.97],
    'Na2O': [0.29, 0.85, 1.44, 1.03, 1.88, 1.9, 1.57, 1.14, 2.64],
    'K2O': [2.04, 2.98, 4.22, 1.66, 5.34, 5.66, 6.28, 5.12, 4.54],
    'TiO2': [1.64, 0.82, 0.45, 0.89, 0.44, 0.45, 0.51, 0.54, 0.37]
}
df = pd.DataFrame(data)
bedrock_depth = df['Depth'].max()

df['R'] = df['SiO2'] / df['Al2O3']
df['WIP'] = 100 * ((2*df['Na2O']/0.35) + (df['MgO']/0.9) + (2*df['K2O']/0.25) + (df['CaO']/0.7))
df['V'] = (df['Al2O3'] + df['K2O']) / (df['MgO'] + df['CaO'] + df['Na2O'])
df['CIA'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O'] + df['K2O']))
df['CIW'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O']))
df['PIA'] = 100 * ((df['Al2O3'] - df['K2O']) / (df['Al2O3'] + df['CaO'] + df['Na2O'] - df['K2O']))
s_t, s_a, a_t = df['SiO2']/df['TiO2'], df['SiO2']/df['Al2O3'], df['Al2O3']/df['TiO2']
df['STI'] = 100 * (s_t / (s_t + s_a + a_t))

# --- 3. PLOTTING LOGIC ---
indices_config = {
    'R': {'c': '#E6194B', 'm': 'o'}, 'WIP': {'c': '#3CB44B', 'm': 's'},
    'V': {'c': '#4363D8', 'm': '^'}, 'STI': {'c': '#F58231', 'm': 'D'},
    'CIA': {'c': '#911EB4', 'm': 'v'}, 'CIW': {'c': '#42D4F4', 'm': '*'},
    'PIA': {'c': '#f032e6', 'm': 'p'}
}

group1 = ['R','V']
group2 = ['CIA', 'CIW', 'PIA', 'STI']
group3 = ['WIP']
all_indices = list(indices_config.keys())

def save_styled_plot(filename, subset, is_log=False):
    fig, ax = plt.subplots(figsize=(2.5, 5))
    for idx in subset:
        ax.plot(df[idx], df['Depth'], marker=indices_config[idx]['m'], 
                color=indices_config[idx]['c'], label=idx)
    
    if is_log: ax.set_xscale('log')
    
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    ax.set_xlabel("Weathering Index Value" + ("\n(Log Scale)" if is_log else ""), fontweight='bold', labelpad=15)
    plt.title('Depth-alteration Profile (Log Scale)' if is_log else 'Depth-alteration Profile', fontsize=14, fontweight='bold', pad=60)
    ax.set_ylabel("Depth (m)", fontweight='bold')
    ax.axhline(y=bedrock_depth, color='black', linestyle='--', linewidth=2, label='Bedrock')
    ax.grid(True, which='both', linestyle='-', alpha=0.8)
    ax.legend(loc='center left', bbox_to_anchor=(1.5, 0.5), frameon=True)
    
    plt.savefig(os.path.join(output_folder, filename), dpi=300, bbox_inches='tight')
    plt.close()

# --- 4. EXECUTION ---
save_styled_plot("Group_1.svg", group1)
save_styled_plot("Group_2.svg", group2)
save_styled_plot("Group_3.svg", group3)
save_styled_plot("Combined_Indices.svg", all_indices)
save_styled_plot("Combined_Log_Profile.svg", all_indices, is_log=True)

print(f"Success! The 4 requested charts have been saved to: {output_folder}")
# Out:
# Success! The 4 requested charts have been saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\Himalaya_1

# %%
# Anini, Arunachal Himalaya
import pandas as pd
import matplotlib.pyplot as plt
import os

# --- 1. CONFIGURATION ---
output_folder = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\Himalaya_2"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# HIGH READABILITY SETTINGS (Optimized for A4 at 30cm)
plt.rcParams.update({
    'font.size': 13,            # Base font size increased
    'axes.labelsize': 11,       # Axis labels
    'axes.titlesize': 12,       # Plot titles
    'legend.fontsize': 9,      # Legend text
    'xtick.labelsize': 9,      # Tick labels
    'ytick.labelsize': 9,
    'lines.linewidth': 1.5,     # Significantly thicker lines
    'lines.markersize': 5,      # Larger markers for quick identification
    'axes.linewidth': 1,      # Thicker axis spines
    'grid.linewidth': 0.5,      # Visible but not distracting grid
    'font.family': 'sans-serif' # Cleaner for technical reading
})

# --- 2. DATA & CALCULATIONS ---
data = {
    'Depth': [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5],
    'SiO2': [50.9, 51.0, 51.5, 51.4, 48.1, 49.0, 49.1, 50.7, 51.2, 51.5, 52.2],
    'Al2O3': [15.47, 16.41, 16.24, 16.36, 17.32, 17.31, 17.13, 17.0, 16.3, 16.1, 15.81],
    'Fe2O3': [4.15, 7.6, 9.21, 12.01, 14.7, 13.31, 10.84, 10.44, 9.59, 10.49, 9.42],
    'MgO': [1.46, 1.51, 2.16, 2.42, 2.98, 3.12, 3.68, 3.65, 4.64, 4.45, 4.84],
    'CaO': [0.59, 0.57, 0.46, 0.46, 0.48, 0.95, 2.73, 4.75, 7.86, 8.14, 9.39],
    'Na2O': [0.27, 0.28, 0.29, 0.29, 0.26, 0.35, 0.72, 2.05, 2.78, 3.12, 3.33],
    'K2O': [1.65, 1.71, 2.02, 2.25, 2.13, 1.94, 1.54, 1.0, 0.87, 0.76, 0.66],
    'TiO2': [0.92, 0.92, 1.27, 1.27, 1.27, 1.3, 1.22, 0.8, 0.98, 0.93, 0.89]
}

df = pd.DataFrame(data)
bedrock_depth = df['Depth'].max()

df['R'] = df['SiO2'] / df['Al2O3']
df['WIP'] = 100 * ((2*df['Na2O']/0.35) + (df['MgO']/0.9) + (2*df['K2O']/0.25) + (df['CaO']/0.7))
df['V'] = (df['Al2O3'] + df['K2O']) / (df['MgO'] + df['CaO'] + df['Na2O'])
df['CIA'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O'] + df['K2O']))
df['CIW'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O']))
df['PIA'] = 100 * ((df['Al2O3'] - df['K2O']) / (df['Al2O3'] + df['CaO'] + df['Na2O'] - df['K2O']))
s_t, s_a, a_t = df['SiO2']/df['TiO2'], df['SiO2']/df['Al2O3'], df['Al2O3']/df['TiO2']
df['STI'] = 100 * (s_t / (s_t + s_a + a_t))

# --- 3. PLOTTING LOGIC ---
indices_config = {
    'R': {'c': '#E6194B', 'm': 'o'}, 'WIP': {'c': '#3CB44B', 'm': 's'},
    'V': {'c': '#4363D8', 'm': '^'}, 'STI': {'c': '#F58231', 'm': 'D'},
    'CIA': {'c': '#911EB4', 'm': 'v'}, 'CIW': {'c': '#42D4F4', 'm': '*'},
    'PIA': {'c': '#f032e6', 'm': 'p'}
}

group1 = ['R','V']
group2 = ['CIA', 'CIW', 'PIA', 'STI']
group3 = ['WIP']
all_indices = list(indices_config.keys())

def save_styled_plot(filename, subset, is_log=False):
    fig, ax = plt.subplots(figsize=(2.5, 5))
    for idx in subset:
        ax.plot(df[idx], df['Depth'], marker=indices_config[idx]['m'], 
                color=indices_config[idx]['c'], label=idx)
    
    if is_log: ax.set_xscale('log')
    
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    ax.set_xlabel("Weathering Index Value" + ("\n(Log Scale)" if is_log else ""), fontweight='bold', labelpad=15)
    plt.title('Depth-alteration Profile (Log Scale)' if is_log else 'Depth-alteration Profile', fontsize=14, fontweight='bold', pad=60)
    ax.set_ylabel("Depth (m)", fontweight='bold')
    #ax.axhline(y=bedrock_depth, color='black', linestyle='--', linewidth=2, label='Bedrock')
    ax.grid(True, which='both', linestyle='-', alpha=0.8)
    ax.legend(loc='center left', bbox_to_anchor=(1.5, 0.5), frameon=True)
    
    plt.savefig(os.path.join(output_folder, filename), dpi=300, bbox_inches='tight')
    plt.close()

# --- 4. EXECUTION ---
save_styled_plot("Group_1.svg", group1)
save_styled_plot("Group_2.svg", group2)
save_styled_plot("Group_3.svg", group3)
save_styled_plot("Combined_Indices.svg", all_indices)
save_styled_plot("Combined_Log_Profile.svg", all_indices, is_log=True)

print(f"Success! The 4 requested charts have been saved to: {output_folder}")
# Out:
# Success! The 4 requested charts have been saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\Himalaya_2

# %%
# Kanjirapalli series
import pandas as pd
import matplotlib.pyplot as plt
import os

# --- 1. CONFIGURATION ---
output_folder = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\WG_1"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# HIGH READABILITY SETTINGS (Optimized for A4 at 30cm)
plt.rcParams.update({
    'font.size': 13,            # Base font size increased
    'axes.labelsize': 11,       # Axis labels
    'axes.titlesize': 12,       # Plot titles
    'legend.fontsize': 9,      # Legend text
    'xtick.labelsize': 9,      # Tick labels
    'ytick.labelsize': 9,
    'lines.linewidth': 1.5,     # Significantly thicker lines
    'lines.markersize': 5,      # Larger markers for quick identification
    'axes.linewidth': 1,      # Thicker axis spines
    'grid.linewidth': 0.5,      # Visible but not distracting grid
    'font.family': 'sans-serif' # Cleaner for technical reading
})

# --- 2. DATA & CALCULATIONS ---
data = {
    'Depth': ['0-13', '13-32', '32-56', '56-83', '83-112', '112-150'],
    'SiO2': [45.4, 37.9, 37.3, 36.1, 33.7, 33.0],
    'Al2O3': [26.1, 27.3, 30.9, 27.6, 30.0, 31.3],
    'Fe2O3': [6.4, 12.7, 11.6, 14.9, 14.9, 12.7],
    'MgO': [0.74, 0.49, 0.67, 0.48, 0.31, 0.29],
    'CaO': [0.74, 0.46, 0.54, 0.57, 0.52, 0.42],
    'Na2O': [0.54, 0.17, 0.17, 0.19, 0.13, 0.15],
    'K2O': [0.52, 0.51, 0.53, 0.63, 0.65, 0.50],
    'TiO2': [1.1, 1.1, 1.0, 1.1, 1.2, 1.2]
}

df = pd.DataFrame(data)
bedrock_depth = df['Depth'].max()

df['R'] = df['SiO2'] / df['Al2O3']
df['WIP'] = 100 * ((2*df['Na2O']/0.35) + (df['MgO']/0.9) + (2*df['K2O']/0.25) + (df['CaO']/0.7))
df['V'] = (df['Al2O3'] + df['K2O']) / (df['MgO'] + df['CaO'] + df['Na2O'])
df['CIA'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O'] + df['K2O']))
df['CIW'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O']))
df['PIA'] = 100 * ((df['Al2O3'] - df['K2O']) / (df['Al2O3'] + df['CaO'] + df['Na2O'] - df['K2O']))
s_t, s_a, a_t = df['SiO2']/df['TiO2'], df['SiO2']/df['Al2O3'], df['Al2O3']/df['TiO2']
df['STI'] = 100 * (s_t / (s_t + s_a + a_t))

# --- 3. PLOTTING LOGIC ---
indices_config = {
    'R': {'c': '#E6194B', 'm': 'o'}, 'WIP': {'c': '#3CB44B', 'm': 's'},
    'V': {'c': '#4363D8', 'm': '^'}, 'STI': {'c': '#F58231', 'm': 'D'},
    'CIA': {'c': '#911EB4', 'm': 'v'}, 'CIW': {'c': '#42D4F4', 'm': '*'},
    'PIA': {'c': '#f032e6', 'm': 'p'}
}

group1 = ['R','V']
group2 = ['CIA', 'CIW', 'PIA', 'STI']
group3 = ['WIP']
all_indices = list(indices_config.keys())

def save_styled_plot(filename, subset, is_log=False):
    fig, ax = plt.subplots(figsize=(2.5, 5))
    for idx in subset:
        ax.plot(df[idx], df['Depth'], marker=indices_config[idx]['m'], 
                color=indices_config[idx]['c'], label=idx)
    
    if is_log: ax.set_xscale('log')
    
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    ax.set_xlabel("Weathering Index Value" + ("\n(Log Scale)" if is_log else ""), fontweight='bold', labelpad=15)
    plt.title('Depth-alteration Profile (Log Scale)' if is_log else 'Depth-alteration Profile', fontsize=14, fontweight='bold', pad=60)
    ax.set_ylabel("Depth (m)", fontweight='bold')
    #ax.axhline(y=bedrock_depth, color='black', linestyle='--', linewidth=2, label='Bedrock')
    ax.grid(True, which='both', linestyle='-', alpha=0.8)
    ax.legend(loc='center left', bbox_to_anchor=(1.5, 0.5), frameon=True)
    
    plt.savefig(os.path.join(output_folder, filename), dpi=300, bbox_inches='tight')
    plt.close()

# --- 4. EXECUTION ---
save_styled_plot("Group_1.svg", group1)
save_styled_plot("Group_2.svg", group2)
save_styled_plot("Group_3.svg", group3)
save_styled_plot("Combined_Indices.svg", all_indices)
save_styled_plot("Combined_Log_Profile.svg", all_indices, is_log=True)

print(f"Success! The 4 requested charts have been saved to: {output_folder}")
# Out:
# Success! The 4 requested charts have been saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\WG_1

# %%
# Madayi village
import pandas as pd
import matplotlib.pyplot as plt
import os

# --- 1. CONFIGURATION ---
output_folder = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\WG_2"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# HIGH READABILITY SETTINGS (Optimized for A4 at 30cm)
plt.rcParams.update({
    'font.size': 13,            # Base font size increased
    'axes.labelsize': 11,       # Axis labels
    'axes.titlesize': 12,       # Plot titles
    'legend.fontsize': 9,      # Legend text
    'xtick.labelsize': 9,      # Tick labels
    'ytick.labelsize': 9,
    'lines.linewidth': 1.5,     # Significantly thicker lines
    'lines.markersize': 5,      # Larger markers for quick identification
    'axes.linewidth': 1,      # Thicker axis spines
    'grid.linewidth': 0.5,      # Visible but not distracting grid
    'font.family': 'sans-serif' # Cleaner for technical reading
})

# --- 2. DATA & CALCULATIONS ---
data = {
    'Depth': [0, 2.2, 3.7, 4.2, 4.7, 5.2],
    'SiO2': [9.88, 18.9, 20.8, 42.1, 46.9, 47.6],
    'Al2O3': [27.1, 36.3, 40.8, 32.1, 29.2, 30.5],
    'Fe2O3': [51.7, 34.3, 17.1, 9.39, 7.11, 8.81],
    'MgO': [0, 0, 0.21, 0.1, 0.13, 0.09],
    'CaO': [0.06, 0.11, 0.05, 0.23, 0.25, 0.18],
    'Na2O': [0, 0, 0, 0.07, 0.02, 0.07],
    'K2O': [0.02, 0.02, 0.8, 0.22, 0.2, 0.14],
    'TiO2': [1.87, 2.33, 3.46, 1.95, 1.9, 1.7]
}


df = pd.DataFrame(data)
bedrock_depth = df['Depth'].max()

df['R'] = df['SiO2'] / df['Al2O3']
df['WIP'] = 100 * ((2*df['Na2O']/0.35) + (df['MgO']/0.9) + (2*df['K2O']/0.25) + (df['CaO']/0.7))
df['V'] = (df['Al2O3'] + df['K2O']) / (df['MgO'] + df['CaO'] + df['Na2O'])
df['CIA'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O'] + df['K2O']))
df['CIW'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O']))
df['PIA'] = 100 * ((df['Al2O3'] - df['K2O']) / (df['Al2O3'] + df['CaO'] + df['Na2O'] - df['K2O']))
s_t, s_a, a_t = df['SiO2']/df['TiO2'], df['SiO2']/df['Al2O3'], df['Al2O3']/df['TiO2']
df['STI'] = 100 * (s_t / (s_t + s_a + a_t))

# --- 3. PLOTTING LOGIC ---
indices_config = {
    'R': {'c': '#E6194B', 'm': 'o'}, 'WIP': {'c': '#3CB44B', 'm': 's'},
    'V': {'c': '#4363D8', 'm': '^'}, 'STI': {'c': '#F58231', 'm': 'D'},
    'CIA': {'c': '#911EB4', 'm': 'v'}, 'CIW': {'c': '#42D4F4', 'm': '*'},
    'PIA': {'c': '#f032e6', 'm': 'p'}
}

group1 = ['R','V']
group2 = ['CIA', 'CIW', 'PIA', 'STI']
group3 = ['WIP']
all_indices = list(indices_config.keys())

def save_styled_plot(filename, subset, is_log=False):
    fig, ax = plt.subplots(figsize=(2.5, 5))
    for idx in subset:
        ax.plot(df[idx], df['Depth'], marker=indices_config[idx]['m'], 
                color=indices_config[idx]['c'], label=idx)
    
    if is_log: ax.set_xscale('log')
    
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    ax.set_xlabel("Weathering Index Value" + ("\n(Log Scale)" if is_log else ""), fontweight='bold', labelpad=15)
    plt.title('Depth-alteration Profile (Log Scale)' if is_log else 'Depth-alteration Profile', fontsize=14, fontweight='bold', pad=60)
    ax.set_ylabel("Depth (m)", fontweight='bold')
    #ax.axhline(y=bedrock_depth, color='black', linestyle='--', linewidth=2, label='Bedrock')
    ax.grid(True, which='both', linestyle='-', alpha=0.8)
    ax.legend(loc='center left', bbox_to_anchor=(1.5, 0.5), frameon=True)
    
    plt.savefig(os.path.join(output_folder, filename), dpi=300, bbox_inches='tight')
    plt.close()

# --- 4. EXECUTION ---
save_styled_plot("Group_1.svg", group1)
save_styled_plot("Group_2.svg", group2)
save_styled_plot("Group_3.svg", group3)
save_styled_plot("Combined_Indices.svg", all_indices)
save_styled_plot("Combined_Log_Profile.svg", all_indices, is_log=True)

print(f"Success! The 4 requested charts have been saved to: {output_folder}")
# Out:
# Success! The 4 requested charts have been saved to: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\WG_2

# %%
data1 = {
    'Depth': [0.25, 0.5, 0.75, 1, 2, 3, 4, 5, 6.0], 
    'SiO2': [66.89, 67.12, 63.39, 65.06, 61.23, 64.05, 61.86, 62.34, 73.34],
    'Al2O3': [17.68, 17.7, 14.82, 16.63, 10.21, 11.24, 10.63, 11.92, 14.26],
    'MgO': [2.36, 1.29, 0.72, 1.42, 0.85, 0.61, 0.81, 0.63, 0.73],
    'CaO': [0.46, 0.69, 0.85, 0.67, 0.64, 0.73, 0.75, 0.62, 0.97],
    'Na2O': [0.29, 0.85, 1.44, 1.03, 1.88, 1.9, 1.57, 1.14, 2.64],
    'K2O': [2.04, 2.98, 4.22, 1.66, 5.34, 5.66, 6.28, 5.12, 4.54],
    'TiO2': [1.64, 0.82, 0.45, 0.89, 0.44, 0.45, 0.51, 0.54, 0.37]
}

data2 = {
    'Depth': [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5],
    'SiO2': [50.9, 51.0, 51.5, 51.4, 48.1, 49.0, 49.1, 50.7, 51.2, 51.5, 52.2],
    'Al2O3': [15.47, 16.41, 16.24, 16.36, 17.32, 17.31, 17.13, 17.0, 16.3, 16.1, 15.81],
    'Fe2O3': [4.15, 7.6, 9.21, 12.01, 14.7, 13.31, 10.84, 10.44, 9.59, 10.49, 9.42],
    'MgO': [1.46, 1.51, 2.16, 2.42, 2.98, 3.12, 3.68, 3.65, 4.64, 4.45, 4.84],
    'CaO': [0.59, 0.57, 0.46, 0.46, 0.48, 0.95, 2.73, 4.75, 7.86, 8.14, 9.39],
    'Na2O': [0.27, 0.28, 0.29, 0.29, 0.26, 0.35, 0.72, 2.05, 2.78, 3.12, 3.33],
    'K2O': [1.65, 1.71, 2.02, 2.25, 2.13, 1.94, 1.54, 1.0, 0.87, 0.76, 0.66],
    'TiO2': [0.92, 0.92, 1.27, 1.27, 1.27, 1.3, 1.22, 0.8, 0.98, 0.93, 0.89]
}

data3 = {
    'Depth': ['0-13', '13-32', '32-56', '56-83', '83-112', '112-150'],
    'SiO2': [45.4, 37.9, 37.3, 36.1, 33.7, 33.0],
    'Al2O3': [26.1, 27.3, 30.9, 27.6, 30.0, 31.3],
    'Fe2O3': [6.4, 12.7, 11.6, 14.9, 14.9, 12.7],
    'MgO': [0.74, 0.49, 0.67, 0.48, 0.31, 0.29],
    'CaO': [0.74, 0.46, 0.54, 0.57, 0.52, 0.42],
    'Na2O': [0.54, 0.17, 0.17, 0.19, 0.13, 0.15],
    'K2O': [0.52, 0.51, 0.53, 0.63, 0.65, 0.50],
    'TiO2': [1.1, 1.1, 1.0, 1.1, 1.2, 1.2]
}

data4 = {
    'Depth': [0, 2.2, 3.7, 4.2, 4.7, 5.2],
    'SiO2': [9.88, 18.9, 20.8, 42.1, 46.9, 47.6],
    'Al2O3': [27.1, 36.3, 40.8, 32.1, 29.2, 30.5],
    'Fe2O3': [51.7, 34.3, 17.1, 9.39, 7.11, 8.81],
    'MgO': [0, 0, 0.21, 0.1, 0.13, 0.09],
    'CaO': [0.06, 0.11, 0.05, 0.23, 0.25, 0.18],
    'Na2O': [0, 0, 0, 0.07, 0.02, 0.07],
    'K2O': [0.02, 0.02, 0.8, 0.22, 0.2, 0.14],
    'TiO2': [1.87, 2.33, 3.46, 1.95, 1.9, 1.7]
}
# Weathering Indices
df['R'] = df['SiO2'] / df['Al2O3']
df['WIP'] = 100 * ((2*df['Na2O']/0.35) + (df['MgO']/0.9) + (2*df['K2O']/0.25) + (df['CaO']/0.7))
df['V'] = (df['Al2O3'] + df['K2O']) / (df['MgO'] + df['CaO'] + df['Na2O'])
df['CIA'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O'] + df['K2O']))
df['CIW'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O']))
df['PIA'] = 100 * ((df['Al2O3'] - df['K2O']) / (df['Al2O3'] + df['CaO'] + df['Na2O'] - df['K2O']))
s_t, s_a, a_t = df['SiO2']/df['TiO2'], df['SiO2']/df['Al2O3'], df['Al2O3']/df['TiO2']
df['STI'] = 100 * (s_t / (s_t + s_a + a_t))

# %%
import pandas as pd
import os

# Your provided data
data_dict = {
    "weathering_1": {
        'Depth': [0.25, 0.5, 0.75, 1, 2, 3, 4, 5, 6.0], 
        'SiO2': [66.89, 67.12, 63.39, 65.06, 61.23, 64.05, 61.86, 62.34, 73.34],
        'Al2O3': [17.68, 17.7, 14.82, 16.63, 10.21, 11.24, 10.63, 11.92, 14.26],
        'MgO': [2.36, 1.29, 0.72, 1.42, 0.85, 0.61, 0.81, 0.63, 0.73],
        'CaO': [0.46, 0.69, 0.85, 0.67, 0.64, 0.73, 0.75, 0.62, 0.97],
        'Na2O': [0.29, 0.85, 1.44, 1.03, 1.88, 1.9, 1.57, 1.14, 2.64],
        'K2O': [2.04, 2.98, 4.22, 1.66, 5.34, 5.66, 6.28, 5.12, 4.54],
        'TiO2': [1.64, 0.82, 0.45, 0.89, 0.44, 0.45, 0.51, 0.54, 0.37]
    },
    "weathering_2": {
        'Depth': [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5],
        'SiO2': [50.9, 51.0, 51.5, 51.4, 48.1, 49.0, 49.1, 50.7, 51.2, 51.5, 52.2],
        'Al2O3': [15.47, 16.41, 16.24, 16.36, 17.32, 17.31, 17.13, 17.0, 16.3, 16.1, 15.81],
        'Fe2O3': [4.15, 7.6, 9.21, 12.01, 14.7, 13.31, 10.84, 10.44, 9.59, 10.49, 9.42],
        'MgO': [1.46, 1.51, 2.16, 2.42, 2.98, 3.12, 3.68, 3.65, 4.64, 4.45, 4.84],
        'CaO': [0.59, 0.57, 0.46, 0.46, 0.48, 0.95, 2.73, 4.75, 7.86, 8.14, 9.39],
        'Na2O': [0.27, 0.28, 0.29, 0.29, 0.26, 0.35, 0.72, 2.05, 2.78, 3.12, 3.33],
        'K2O': [1.65, 1.71, 2.02, 2.25, 2.13, 1.94, 1.54, 1.0, 0.87, 0.76, 0.66],
        'TiO2': [0.92, 0.92, 1.27, 1.27, 1.27, 1.3, 1.22, 0.8, 0.98, 0.93, 0.89]
    },
    "weathering_3": {
        'Depth': ['0-13', '13-32', '32-56', '56-83', '83-112', '112-150'],
        'SiO2': [45.4, 37.9, 37.3, 36.1, 33.7, 33.0],
        'Al2O3': [26.1, 27.3, 30.9, 27.6, 30.0, 31.3],
        'Fe2O3': [6.4, 12.7, 11.6, 14.9, 14.9, 12.7],
        'MgO': [0.74, 0.49, 0.67, 0.48, 0.31, 0.29],
        'CaO': [0.74, 0.46, 0.54, 0.57, 0.52, 0.42],
        'Na2O': [0.54, 0.17, 0.17, 0.19, 0.13, 0.15],
        'K2O': [0.52, 0.51, 0.53, 0.63, 0.65, 0.50],
        'TiO2': [1.1, 1.1, 1.0, 1.1, 1.2, 1.2]
    },
    "weathering_4": {
        'Depth': [0, 2.2, 3.7, 4.2, 4.7, 5.2],
        'SiO2': [9.88, 18.9, 20.8, 42.1, 46.9, 47.6],
        'Al2O3': [27.1, 36.3, 40.8, 32.1, 29.2, 30.5],
        'Fe2O3': [51.7, 34.3, 17.1, 9.39, 7.11, 8.81],
        'MgO': [0, 0, 0.21, 0.1, 0.13, 0.09],
        'CaO': [0.06, 0.11, 0.05, 0.23, 0.25, 0.18],
        'Na2O': [0, 0, 0, 0.07, 0.02, 0.07],
        'K2O': [0.02, 0.02, 0.8, 0.22, 0.2, 0.14],
        'TiO2': [1.87, 2.33, 3.46, 1.95, 1.9, 1.7]
    }
}

# Prompt for the output directory
target_path = r"D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026"

# Ensure the directory exists
if not os.path.exists(target_path):
    os.makedirs(target_path)
    print(f"Created new directory: {target_path}")

for key, data in data_dict.items():
    df = pd.DataFrame(data)
    
    # Calculate Indices
    df['R'] = df['SiO2'] / df['Al2O3']
    df['WIP'] = 100 * ((2*df['Na2O']/0.35) + (df['MgO']/0.9) + (2*df['K2O']/0.25) + (df['CaO']/0.7))
    df['V'] = (df['Al2O3'] + df['K2O']) / (df['MgO'] + df['CaO'] + df['Na2O'])
    df['CIA'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O'] + df['K2O']))
    df['CIW'] = 100 * (df['Al2O3'] / (df['Al2O3'] + df['CaO'] + df['Na2O']))
    df['PIA'] = 100 * ((df['Al2O3'] - df['K2O']) / (df['Al2O3'] + df['CaO'] + df['Na2O'] - df['K2O']))
    
    s_t, s_a, a_t = df['SiO2']/df['TiO2'], df['SiO2']/df['Al2O3'], df['Al2O3']/df['TiO2']
    df['STI'] = 100 * (s_t / (s_t + s_a + a_t))
    
    # Define file path and save
    file_name = f"{key}_results.csv"
    full_output_path = os.path.join(target_path, file_name)
    df.to_csv(full_output_path, index=False)
    print(f"Successfully saved: {full_output_path}")
# Out:
# Successfully saved: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\weathering_1_results.csv
# Successfully saved: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\weathering_2_results.csv
# Successfully saved: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\weathering_3_results.csv
# Successfully saved: D:\DOCUMENT\Documents\GRADUATION\MSc\CORE\2nd SEM\GS 422 Process Geomorphology, Remote Sensing and GIS\RS REPORT 2026\weathering_4_results.csv
